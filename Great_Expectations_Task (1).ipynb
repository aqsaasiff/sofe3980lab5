# %% [markdown]
# # Great Expectations Task

# %% [markdown]
# ## 1. Install Great Expectations Library

# %%
# !pip install --upgrade pip
# !pip install great_expectations
# !pip install great_expectations==0.15.50
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (25.0.1)
# Requirement already satisfied: great_expectations in /usr/local/lib/python3.11/dist-packages (0.15.50)
# Requirement already satisfied: altair<4.2.1,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (4.2.0)
# Requirement already satisfied: Click>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (8.1.8)
# Requirement already satisfied: colorama>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (0.4.6)
# Requirement already satisfied: cryptography>=3.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (43.0.3)
# Requirement already satisfied: importlib-metadata>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (8.6.1)
# Requirement already satisfied: Ipython>=7.16.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (7.34.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (7.7.1)
# Requirement already satisfied: jinja2>=2.10 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (3.1.6)
# Requirement already satisfied: jsonpatch>=1.22 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (1.33)
# Requirement already satisfied: jsonschema>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (4.23.0)
# Requirement already satisfied: makefun<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (1.15.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (3.26.1)
# Requirement already satisfied: mistune>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (3.1.3)
# Requirement already satisfied: nbformat>=5.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (5.10.4)
# Requirement already satisfied: notebook>=6.4.10 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (6.5.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from great_expectations) (24.2)
# Requirement already satisfied: pydantic<2.0,>=1.10.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (1.10.21)
# Requirement already satisfied: pyparsing>=2.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (2.8.2)
# Requirement already satisfied: pytz>=2021.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (2025.1)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (2.32.3)
# Requirement already satisfied: ruamel.yaml<0.17.18,>=0.16 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (0.17.17)
# Requirement already satisfied: scipy>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (1.14.1)
# Requirement already satisfied: tqdm>=4.59.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (4.12.2)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (5.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (1.26.20)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (1.26.4)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (2.1.4)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from altair<4.2.1,>=4.0.0->great_expectations) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from altair<4.2.1,>=4.0.0->great_expectations) (0.12.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.2->great_expectations) (1.17.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=1.7.0->great_expectations) (3.21.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.10->great_expectations) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch>=1.22->great_expectations) (3.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations) (0.23.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.0->great_expectations) (2.21.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.0->great_expectations) (5.7.2)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (6.4.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (23.1.0)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (6.1.12)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (1.2.0)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->great_expectations) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->great_expectations) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations) (2025.1.31)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.2->great_expectations) (2.22)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations) (1.8.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations) (5.9.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->Ipython>=7.16.3->great_expectations) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.0->great_expectations) (4.3.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (1.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->Ipython>=7.16.3->great_expectations) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->Ipython>=7.16.3->great_expectations) (0.2.13)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=6.4.10->great_expectations) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.4.10->great_expectations) (2.6)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (1.3.1)
# Requirement already satisfied: great_expectations==0.15.50 in /usr/local/lib/python3.11/dist-packages (0.15.50)
# Requirement already satisfied: altair<4.2.1,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (4.2.0)
# Requirement already satisfied: Click>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (8.1.8)
# Requirement already satisfied: colorama>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (0.4.6)
# Requirement already satisfied: cryptography>=3.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (43.0.3)
# Requirement already satisfied: importlib-metadata>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (8.6.1)
# Requirement already satisfied: Ipython>=7.16.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (7.34.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (7.7.1)
# Requirement already satisfied: jinja2>=2.10 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (3.1.6)
# Requirement already satisfied: jsonpatch>=1.22 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (1.33)
# Requirement already satisfied: jsonschema>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (4.23.0)
# Requirement already satisfied: makefun<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (1.15.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (3.26.1)
# Requirement already satisfied: mistune>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (3.1.3)
# Requirement already satisfied: nbformat>=5.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (5.10.4)
# Requirement already satisfied: notebook>=6.4.10 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (6.5.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (24.2)
# Requirement already satisfied: pydantic<2.0,>=1.10.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (1.10.21)
# Requirement already satisfied: pyparsing>=2.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (2.8.2)
# Requirement already satisfied: pytz>=2021.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (2025.1)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (2.32.3)
# Requirement already satisfied: ruamel.yaml<0.17.18,>=0.16 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (0.17.17)
# Requirement already satisfied: scipy>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (1.14.1)
# Requirement already satisfied: tqdm>=4.59.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (4.12.2)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (5.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (1.26.20)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (1.26.4)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (2.1.4)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from altair<4.2.1,>=4.0.0->great_expectations==0.15.50) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from altair<4.2.1,>=4.0.0->great_expectations==0.15.50) (0.12.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.2->great_expectations==0.15.50) (1.17.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=1.7.0->great_expectations==0.15.50) (3.21.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations==0.15.50) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations==0.15.50) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations==0.15.50) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations==0.15.50) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.10->great_expectations==0.15.50) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch>=1.22->great_expectations==0.15.50) (3.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations==0.15.50) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations==0.15.50) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations==0.15.50) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations==0.15.50) (0.23.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.0->great_expectations==0.15.50) (2.21.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.0->great_expectations==0.15.50) (5.7.2)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (6.4.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (23.1.0)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (6.1.12)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (1.2.0)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->great_expectations==0.15.50) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->great_expectations==0.15.50) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations==0.15.50) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations==0.15.50) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations==0.15.50) (2025.1.31)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.2->great_expectations==0.15.50) (2.22)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations==0.15.50) (1.8.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations==0.15.50) (5.9.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->Ipython>=7.16.3->great_expectations==0.15.50) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.0->great_expectations==0.15.50) (4.3.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.15.50) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (1.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->Ipython>=7.16.3->great_expectations==0.15.50) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->Ipython>=7.16.3->great_expectations==0.15.50) (0.2.13)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=6.4.10->great_expectations==0.15.50) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.15.50) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (2.6)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.15.50) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.15.50) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.15.50) (1.3.1)

# %% [markdown]
# ##2. Import Necessary Libraries
#
# > Add blockquote

# %%
import pandas as pd
import great_expectations as gx

# %% [markdown]
# ##3. Load Labels.csv

# %%
import pandas as pd

# Load your dataset (adjust the path if your CSV is elsewhere)
df = pd.read_csv('/content/drive/MyDrive/SOFE3980U-Lab5/Labels.csv')
df.head()
# Out:
#     Timestamp  Car1_Location_X  Car1_Location_Y  Car1_Location_Z  \
# 0  1736796157       -51.402977              143         0.596902
# 1  1736796167       -53.819637              143         0.596902
# 2  1736796178       -50.239144              143         0.596902
# 3  1736796188       -53.707220              143         0.596902
# 4  1736796198       -52.053721              143         0.596902
#
#    Car2_Location_X  Car2_Location_Y  Car2_Location_Z Occluded_Image_view  \
# 0       -59.320270              140         0.596902           A_001.png
# 1       -59.196568              140         0.596902           A_002.png
# 2       -56.744479              140         0.596902           A_003.png
# 3       -57.309380              140         0.596902           A_004.png
# 4       -59.545897              140         0.596902           A_005.png
#
#   Occluding_Car_view Ground_Truth_View  pedestrianLocationX_TopLeft  \
# 0          B_001.png         C_001.png                          593
# 1          B_002.png         C_002.png                          579
# 2          B_003.png         C_003.png                          854
# 3          B_004.png         C_004.png                          549
# 4          B_005.png         C_005.png                          524
#
#    pedestrianLocationY_TopLeft  pedestrianLocationX_BottomRight  \
# 0                          361                              610
# 1                          368                              594
# 2                          720                              854
# 3                          368                              567
# 4                          368                              537
#
#    pedestrianLocationY_BottomRight
# 0                              410
# 1                              415
# 2                              720
# 3                              425
# 4                              413

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Download and upload the [Labels.csv](https://github.com/zubxxr/SOFE3980U-Lab5/blob/main/Labels.csv) into this notebook, and then load the file.

# %% [markdown]
# ##4. Preview the Dataset

# %%
df.head()
# Out:
#     Timestamp  Car1_Location_X  Car1_Location_Y  Car1_Location_Z  \
# 0  1736796157       -51.402977              143         0.596902
# 1  1736796167       -53.819637              143         0.596902
# 2  1736796178       -50.239144              143         0.596902
# 3  1736796188       -53.707220              143         0.596902
# 4  1736796198       -52.053721              143         0.596902
#
#    Car2_Location_X  Car2_Location_Y  Car2_Location_Z Occluded_Image_view  \
# 0       -59.320270              140         0.596902           A_001.png
# 1       -59.196568              140         0.596902           A_002.png
# 2       -56.744479              140         0.596902           A_003.png
# 3       -57.309380              140         0.596902           A_004.png
# 4       -59.545897              140         0.596902           A_005.png
#
#   Occluding_Car_view Ground_Truth_View  pedestrianLocationX_TopLeft  \
# 0          B_001.png         C_001.png                          593
# 1          B_002.png         C_002.png                          579
# 2          B_003.png         C_003.png                          854
# 3          B_004.png         C_004.png                          549
# 4          B_005.png         C_005.png                          524
#
#    pedestrianLocationY_TopLeft  pedestrianLocationX_BottomRight  \
# 0                          361                              610
# 1                          368                              594
# 2                          720                              854
# 3                          368                              567
# 4                          368                              537
#
#    pedestrianLocationY_BottomRight
# 0                              410
# 1                              415
# 2                              720
# 3                              425
# 4                              413

# %% [markdown]
# ##5. Set Up Great Expectations Context and Data Source

# %%
import great_expectations as gx

# Use legacy API to wrap the DataFrame
df_gx = gx.dataset.PandasDataset(df)

# %% [markdown]
# ##6. Define and Create a Data Batch

# %%
# Write code here

# %% [markdown]
# ##7. Define Three Expectations for Column Values

# %% [markdown]
# Using this [link](https://greatexpectations.io/expectations/), choose three expectation functions and apply them to the labels dataset in a relevant manner.
#
# You should replace the 'ExpectColumnValuesToBeBetween' function with other functions you select from the link.
#
# You can also check the format/parameters required of each function when you click "See more" on the function.

# %% [markdown]
# ### Expectation 1

# %%
# Expectation 1: Timestamp should not be null
expectation1 = df_gx.expect_column_values_to_not_be_null("Timestamp")
expectation1
# Out:
# {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_not_be_null",
#     "kwargs": {
#       "column": "Timestamp",
#       "result_format": "BASIC"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 121,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ### Validate Data Against Expectation 1

# %%
expectation1

# %% [markdown]
# ### Expectation 2

# %%
# Expectation 2: Car1_Location_X should be between -1000 and 1000 (example bounds)
expectation2 = df_gx.expect_column_values_to_be_between("Car1_Location_X", min_value=-1000, max_value=1000)
expectation2
# Out:
# {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_be_between",
#     "kwargs": {
#       "column": "Car1_Location_X",
#       "min_value": -1000,
#       "max_value": 1000,
#       "result_format": "BASIC"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 121,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ### Validate Data Against Expectation 2

# %%
expectation2

# %% [markdown]
# ### Expectation 3

# %%
# Expectation 3: Occluded_Image_view should be binary (0 or 1)
expectation3 = df_gx.expect_column_values_to_be_in_set("Occluded_Image_view", [0, 1])
expectation3
# Out:
# {
#   "success": false,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_be_in_set",
#     "kwargs": {
#       "column": "Occluded_Image_view",
#       "value_set": [
#         0,
#         1
#       ],
#       "result_format": "BASIC"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 121,
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_count": 121,
#     "unexpected_percent": 100.0,
#     "unexpected_percent_total": 100.0,
#     "unexpected_percent_nonmissing": 100.0,
#     "partial_unexpected_list": [
#       "A_001.png",
#       "A_002.png",
#       "A_003.png",
#       "A_004.png",
#       "A_005.png",
#       "A_006.png",
#       "A_007.png",
#       "A_008.png",
#       "A_009.png",
#       "A_010.png",
#       "A_011.png",
#       "A_012.png",
#       "A_013.png",
#       "A_014.png",
#       "A_015.png",
#       "A_016.png",
#       "A_017.png",
#       "A_018.png",
#       "A_019.png",
#       "A_020.png"
#     ]
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ### Validate Data Against Expectation 3

# %%
expectation3
